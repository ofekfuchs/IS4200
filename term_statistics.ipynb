# %% [markdown]
# <a href="https://colab.research.google.com/github/ofekfuchs/IS4200/blob/main/term_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Terms and Documents
#
# This first homework assignment starts off with term statistics computations and graphing. In the final section (for CS6200 students), you collect new documents to experiment with.
#
# Read through this Jupyter notebook and fill in the parts marked with `TODO`.

# %% [markdown]
# ## Sample Data
#
# Start by looking at some sample data. We donwload the counts of terms in documents for the first one million tokens of a newswire collection.

# %%
# !wget -O ap201001.json.gz https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# !gunzip ap201001.json.gz
# Out:
# --2023-09-19 20:48:20--  https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz [following]
# --2023-09-19 20:48:20--  https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz [following]
# --2023-09-19 20:48:20--  https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2854711 (2.7M) [application/octet-stream]
# Saving to: ‘ap201001.json.gz’
#
# ap201001.json.gz    100%[===================>]   2.72M  --.-KB/s    in 0.02s
#
# 2023-09-19 20:48:20 (172 MB/s) - ‘ap201001.json.gz’ saved [2854711/2854711]
#
# gzip: ap201001.json already exists; do you wish to overwrite (y or n)? ^C

# %% [markdown]
# We convert this file with one JSON record on each line to a list of dictionaries.

# %%
import json
import pandas as pd
import math
import matplotlib.pyplot as plt
rawfile = open('ap201001.json')
terms = [json.loads(line) for line in rawfile]

# %% [markdown]
# Here are the first ten records, showing the count of each term for each document and field. In this dataset, field only takes the values `body` or `title`.

# %%
terms[1:10]
# Out:
# [{'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'about', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'abuse', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'academy',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'accused',
#   'count': 2},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'actress',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'ad', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'after', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agenda',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agreed',
#   'count': 1}]

# %% [markdown]
# Each record has four fields:
# * `id`, with the identifier for the document;
# * `field`, with the region of the document containing a given term;
# * `term`, with the lower-cased term; and
# * `count`, with the number of times each term occurred in that field and document.

# %% [markdown]
# ## Computing Term Statistics

# %% [markdown]
# If we look at the most frequent terms for a given document, we mostly see common function words, such as `the`, `and`, and `of`. Start exploring the dataset by computing some of these basic term statistics. You can make your life easier using data frame libraries such as `pandas`, core python libraries such as `collections`, or just simple list comprehensions.
#
# Feel free to define helper functions in your code before computing the statistics we're looking for.

# %%
# TODO: Print the 10 terms from document APW_ENG_20100101.0001 with the highest count.
document_id = 'APW_ENG_20100101.0001'
document_terms=[]
for term in terms:
  if term['id']==document_id:
    document_terms.append(term)
top_10_terms = (sorted(document_terms, key=lambda x: x['count'], reverse=True))[:10]
top_10_terms
# Out:
# [{'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'a', 'count': 16},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'the', 'count': 11},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'and', 'count': 10},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'brooks',
#   'count': 10},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'of', 'count': 10},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'to', 'count': 10},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'he', 'count': 9},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'in', 'count': 9},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'gomez', 'count': 8},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'for', 'count': 6}]

# %%
# TODO: Print the 10 terms with the highest total count in the corpus.
df = pd.DataFrame(terms)
top_10_terms_corpus = (df.groupby('term').sum('count').sort_values(by='count', ascending=False))[:10]
top_10_terms_corpus
# Out:
#       count
# term
# the   62216
# to    26931
# in    25659
# a     23383
# of    22326
# and   22125
# said  10888
# for    9716
# on     9382
# that   8942

# %% [markdown]
# Raw counts may not be the most informative statistic. One common improvement is to use *inverse document frequency*, the inverse of the proportion of documents that contain a given term.

# %%
# TODO: Compute the number of distinct documents in the collection.
document_ids = set()
for term in terms:
    document_ids.add(term['id'])
N = len(document_ids)
N
# Out:
# 2778

# %%
# TODO: Compute the number of distinct documents each term appears in
# and store in a dictionary.
df_dict = dict()
for term in terms:
  if term['term'] in df_dict:
    df_dict[term['term']].add(term['id'])
  else:
    df_dict[term['term']] = {term['id']}
term_appears= dict()
for key in df_dict:
  term_appears[key] = len(df_dict[key])
term_appears
# Out:
# {'a': 2571,
#  'about': 1077,
#  'abuse': 26,
#  'academy': 20,
#  'accused': 201,
#  'actress': 23,
#  'ad': 16,
#  'after': 1484,
#  'agenda': 16,
#  'agreed': 163,
#  'all': 708,
#  'along': 220,
#  'already': 321,
#  'also': 1103,
#  'an': 1631,
#  'and': 2521,
#  'apartment': 41,
#  'approved': 56,
#  'arnold': 9,
#  'arrange': 6,
#  'as': 1615,
#  'assaulting': 2,
#  'at': 2020,
#  'audition': 1,
#  'awaiting': 16,
#  'award': 28,
#  'bail': 23,
#  'ballad': 3,
#  'being': 524,
#  'benz': 4,
#  'best': 193,
#  'between': 520,
#  'boone': 1,
#  'borrowed': 13,
#  'brooks': 9,
#  'but': 1499,
#  'by': 1760,
#  'came': 317,
#  'cash': 153,
#  'casting': 4,
#  'certificate': 3,
#  'charged': 172,
#  'charges': 177,
#  'comedian': 7,
#  'comedy': 10,
#  'comment': 237,
#  'companionship': 1,
#  'composer': 5,
#  'concerns': 129,
#  'conning': 1,
#  'couch': 4,
#  'could': 753,
#  'court': 287,
#  'daddy': 1,
#  'damages': 21,
#  'deal': 227,
#  'debby': 1,
#  'declined': 157,
#  "didn't": 258,
#  'directed': 66,
#  'director': 215,
#  'disputed': 56,
#  'divorce': 4,
#  'dreams': 10,
#  'e': 102,
#  'each': 233,
#  'ended': 168,
#  'engagement': 8,
#  'even': 365,
#  'ex': 40,
#  'fact': 88,
#  'fiancee': 2,
#  'fight': 188,
#  'figure': 97,
#  'for': 2180,
#  'former': 426,
#  'friday': 217,
#  'gave': 200,
#  'gift': 17,
#  'gifts': 9,
#  'girls': 21,
#  'gomez': 2,
#  "gomez's": 1,
#  'guilty': 69,
#  'handbag': 2,
#  'has': 1695,
#  'he': 1470,
#  'help': 333,
#  'her': 298,
#  "he's": 119,
#  'hiding': 31,
#  'him': 524,
#  'his': 1186,
#  'hour': 119,
#  'immediately': 229,
#  'in': 2589,
#  'initially': 67,
#  'into': 939,
#  'is': 1850,
#  'it': 1630,
#  'joaly': 1,
#  'joseph': 29,
#  'judge': 108,
#  'june': 164,
#  'keep': 232,
#  'knew': 65,
#  'last': 1044,
#  'lawyer': 106,
#  'learned': 42,
#  'least': 353,
#  'life': 194,
#  'light': 65,
#  'looking': 156,
#  'mail': 47,
#  'make': 422,
#  'manhattan': 16,
#  'marriage': 19,
#  'married': 22,
#  'mercedes': 7,
#  'messages': 26,
#  'met': 138,
#  'million': 482,
#  'money': 239,
#  'months': 371,
#  'most': 549,
#  'movie': 40,
#  'my': 220,
#  'name': 181,
#  'night': 169,
#  'no': 828,
#  'not': 1365,
#  'obvious': 10,
#  'october': 196,
#  'of': 2527,
#  'old': 665,
#  'on': 2306,
#  'one': 1029,
#  'only': 687,
#  'original': 51,
#  'oscar': 17,
#  'other': 1033,
#  'out': 971,
#  'paid': 89,
#  'papers': 22,
#  "party's": 9,
#  'placing': 19,
#  'pleaded': 53,
#  'presents': 12,
#  'pretty': 34,
#  'previously': 97,
#  'pricey': 2,
#  'progressed': 10,
#  'promised': 64,
#  'rape': 20,
#  'rapes': 6,
#  'records': 44,
#  'relationship': 48,
#  'respond': 44,
#  'return': 221,
#  'ring': 19,
#  'roles': 12,
#  'romantic': 5,
#  'rome': 27,
#  'rosemarie': 1,
#  'said': 1928,
#  'same': 235,
#  'schemer': 4,
#  'secrets': 5,
#  'seeking': 152,
#  'series': 172,
#  'settlement': 36,
#  'sexual': 17,
#  'sexually': 6,
#  'share': 137,
#  'she': 343,
#  'show': 237,
#  'single': 84,
#  'six': 395,
#  'song': 7,
#  'songwriter': 2,
#  'specified': 1,
#  'spotted': 7,
#  'stand': 100,
#  'steered': 4,
#  'struck': 133,
#  'sucker': 1,
#  'sued': 27,
#  'sugar': 10,
#  'supposed': 33,
#  'telephone': 58,
#  'terms': 131,
#  'that': 1962,
#  'the': 2696,
#  'their': 985,
#  'then': 456,
#  'there': 782,
#  'they': 994,
#  'throughout': 106,
#  'to': 2482,
#  'trial': 83,
#  'tried': 215,
#  'unless': 41,
#  'up': 1102,
#  'was': 1946,
#  "wasn't": 101,
#  'week': 443,
#  'were': 1274,
#  "weren't": 47,
#  'when': 975,
#  'who': 1267,
#  'william': 25,
#  'winning': 129,
#  'with': 1881,
#  'women': 103,
#  'won': 316,
#  'would': 904,
#  'wrote': 98,
#  'year': 1317,
#  'you': 288,
#  'young': 140,
#  'lawsuit': 40,
#  'settles': 8,
#  'abbas': 32,
#  'aboard': 63,
#  'abou': 1,
#  'accounts': 62,
#  'admits': 8,
#  'adopt': 6,
#  'adviser': 76,
#  'afghan': 109,
#  'africa': 174,
#  'african': 76,
#  'against': 715,
#  'agents': 71,
#  'agrees': 12,
#  'airstrip': 1,
#  'alarming': 7,
#  'albanian': 5,
#  'ali': 84,
#  'allesandro': 1,
#  'american': 410,
#  'angola': 13,
#  'announces': 12,
#  'anti': 199,
#  'any': 557,
#  'appeals': 44,
#  'are': 1287,
#  'arms': 43,
#  'army': 128,
#  'arrested': 193,
#  'athletes': 14,
#  'atrocities': 7,
#  'attack': 382,
#  'attacks': 250,
#  'attempt': 212,
#  'author': 26,
#  'authority': 91,
#  'baez': 1,
#  'baghdad': 47,
#  'bank': 180,
#  'battle': 37,
#  'before': 762,
#  'begin': 92,
#  'biological': 3,
#  'birthdays': 8,
#  'black': 78,
#  'blix': 1,
#  'bloodshed': 24,
#  'bordering': 2,
#  'borders': 42,
#  'bosnia': 5,
#  'brazil': 47,
#  'breakaway': 5,
#  'breaks': 28,
#  'british': 262,
#  'canal': 10,
#  'capek': 1,
#  'capture': 44,
#  'captured': 50,
#  'cargo': 24,
#  'carrying': 110,
#  'cease': 19,
#  'censorship': 9,
#  'central': 210,
#  'chairman': 115,
#  'chechen': 2,
#  'chemical': 36,
#  'citizens': 98,
#  'city': 362,
#  'claims': 95,
#  'close': 255,
#  'closes': 11,
#  'commander': 45,
#  'condoleezza': 1,
#  'congo': 6,
#  'congress': 77,
#  'construction': 104,
#  'council': 94,
#  'countries': 285,
#  'country': 466,
#  "country's": 222,
#  'crashes': 15,
#  'create': 67,
#  'credible': 7,
#  'criticized': 66,
#  'cuba': 78,
#  'curb': 18,
#  'cut': 173,
#  'cyril': 15,
#  'czechoslovak': 1,
#  'dagestan': 11,
#  'daoud': 2,
#  'data': 115,
#  'date': 89,
#  'day': 683,
#  'days': 302,
#  'deaths': 108,
#  'debate': 48,
#  'decisive': 19,
#  'declaration': 4,
#  'declares': 3,
#  'defense': 195,
#  'definite': 3,
#  'delegation': 34,
#  'demanding': 22,
#  'designed': 94,
#  'destruction': 33,
#  'develop': 44,
#  'die': 38,
#  'disarm': 3,
#  'down': 617,
#  'drove': 34,
#  'early': 359,
#  'egyptian': 57,
#  "egypt's": 34,
#  'eight': 287,
#  'elbaradei': 1,
#  'elected': 32,
#  'elects': 1,
#  'elite': 12,
#  'emergency': 102,
#  'end': 297,
#  'ends': 50,
#  'english': 58,
#  'erupts': 4,
#  'escapes': 3,
#  'estimated': 102,
#  'ethnic': 36,
#  'evidence': 107,
#  'executed': 13,
#  'fairfax': 1,
#  'federal': 271,
#  'fire': 171,
#  'first': 937,
#  'flight': 176,
#  'folk': 1,
#  'forces': 224,
#  'foreshadowing': 1,
#  'four': 503,
#  'france': 207,
#  'free': 154,
#  'french': 137,
#  'from': 1849,
#  'games': 190,
#  'give': 271,
#  'government': 739,
#  'gregory': 18,
#  'group': 504,
#  'growing': 130,
#  'grozny': 1,
#  'guards': 79,
#  'guinea': 8,
#  'guitarist': 5,
#  'gulf': 56,
#  'gun': 50,
#  'gunmen': 44,
#  'had': 1299,
#  'hamid': 26,
#  'handing': 17,
#  'hans': 8,
#  'hashim': 36,
#  'have': 1462,
#  'having': 139,
#  'head': 279,
#  'headquarters': 37,
#  'herzegovina': 2,
#  'highlights': 11,
#  'hindu': 10,
#  'history': 133,
#  'hosni': 14,
#  'hospital': 156,
#  'hostages': 5,
#  'house': 263,
#  'however': 334,
#  'human': 117,
#  'hussein': 7,
#  'ii': 63,
#  'illegally': 20,
#  'impending': 3,
#  'inaugurates': 2,
#  'including': 619,
#  'independence': 30,
#  'inmates': 15,
#  'inspectors': 11,
#  'insurgent': 15,
#  'intelligence': 232,
#  'interim': 32,
#  'invade': 4,
#  'investigation': 148,
#  'iran': 103,
#  'iranian': 55,
#  'iraq': 126,
#  'islamic': 139,
#  'israel': 120,
#  'israeli': 77,
#  'its': 1170,
#  'jan': 295,
#  'january': 139,
#  'jassy': 1,
#  'jets': 25,
#  'jimmy': 12,
#  'joan': 16,
#  'jonas': 3,
#  'karel': 4,
#  'karzai': 22,
#  'killing': 197,
#  'killings': 39,
#  'kizlyar': 1,
#  'kosovo': 7,
#  "kosovo's": 4,
#  'lake': 22,
#  'landing': 27,
#  'laureate': 3,
#  'leader': 239,
#  'leaks': 1,
#  'lebanon': 43,
#  'led': 336,
#  'left': 366,
#  'liberation': 12,
#  'libya': 27,
#  'link': 39,
#  'ludovisi': 1,
#  'luzon': 1,
#  'm': 122,
#  'mahmoud': 60,
#  'major': 342,
#  'mandate': 10,
#  'margin': 2,
#  'mass': 109,
#  'memorandum': 2,
#  'mideast': 27,
#  'militants': 172,
#  'military': 212,
#  'minister': 383,
#  'mirage': 2,
#  'mohamed': 16,
#  'month': 580,
#  'more': 1121,
#  'morning': 150,
#  'moved': 149,
#  'mubarak': 15,
#  'munich': 16,
#  'n': 106,
#  'nasser': 23,
#  'national': 445,
#  'nationalist': 4,
#  'nations': 183,
#  'new': 1047,
#  'nile': 5,
#  'nixon': 2,
#  'north': 252,
#  'nothing': 113,
#  'nuclear': 67,
#  'occupation': 3,
#  'off': 621,
#  'officials': 721,
#  'olympic': 54,
#  'opens': 27,
#  'or': 958,
#  'others': 264,
#  'over': 968,
#  'overseeing': 10,
#  'own': 260,
#  'pact': 10,
#  'page': 33,
#  'palace': 15,
#  'palestinian': 73,
#  'panama': 1,
#  'panamanians': 1,
#  'parental': 1,
#  'paris': 61,
#  'parliament': 96,
#  'peace': 86,
#  'people': 788,
#  "people's": 43,
#  'persian': 20,
#  'philippines': 14,
#  'photographer': 8,
#  'pill': 8,
#  'plan': 176,
#  'plane': 153,
#  'planned': 141,
#  'poet': 5,
#  'pope': 16,
#  'population': 89,
#  'positions': 23,
#  'possessed': 2,
#  'power': 232,
#  'pregnancy': 5,
#  'prepared': 50,
#  'president': 559,
#  'presidential': 74,
#  'press': 599,
#  'prime': 198,
#  'prison': 157,
#  'proclaim': 1,
#  'proverb': 2,
#  'proving': 8,
#  'pumping': 7,
#  'ramaphosa': 1,
#  'rate': 117,
#  'reagan': 13,
#  'rebel': 24,
#  'rebels': 50,
#  'received': 213,
#  'regime': 22,
#  'rein': 8,
#  'reinstates': 4,
#  'release': 108,
#  'releases': 28,
#  'renew': 7,
#  'republic': 88,
#  'resulting': 26,
#  'retaken': 1,
#  'revolution': 16,
#  'revolutionary': 12,
#  'rhodesia': 1,
#  'rice': 15,
#  'richard': 82,
#  'rights': 123,
#  'riot': 26,
#  'rioting': 8,
#  'river': 45,
#  'rock': 39,
#  'ronald': 20,
#  'ruled': 60,
#  'rules': 104,
#  'russia': 149,
#  'russian': 48,
#  's': 1191,
#  'saddam': 10,
#  'sales': 142,
#  'samantar': 1,
#  'saturday': 348,
#  'savimbi': 1,
#  'schools': 57,
#  'second': 603,
#  'secrecy': 13,
#  'security': 562,
#  'seize': 12,
#  'sekou': 1,
#  'sell': 75,
#  'send': 65,
#  'serbia': 39,
#  'serbs': 6,
#  'set': 423,
#  'setting': 79,
#  'shot': 169,
#  'showed': 205,
#  'sign': 123,
#  'since': 796,
#  'singer': 27,
#  'smoking': 19,
#  'soldiers': 92,
#  'somalia': 71,
#  'some': 692,
#  'sought': 114,
#  'south': 390,
#  'southeastern': 18,
#  'soviet': 28,
#  'spain': 144,
#  'stanleyville': 1,
#  'state': 505,
#  'states': 495,
#  'station': 63,
#  'streets': 34,
#  'students': 32,
#  'suspected': 212,
#  'swiss': 92,
#  "switzerland's": 6,
#  'symbolic': 5,
#  'syria': 49,
#  'talks': 96,
#  'teenage': 6,
#  'tell': 57,
#  'thaci': 1,
#  'than': 955,
#  'things': 124,
#  'this': 1184,
#  'thomas': 41,
#  'those': 419,
#  'thought': 120,
#  'three': 830,
#  'today': 121,
#  "today's": 27,
#  'toure': 5,
#  "town's": 5,
#  'township': 5,
#  'trade': 117,
#  'treaty': 17,
#  'tries': 17,
#  'troops': 151,
#  'try': 149,
#  'trying': 275,
#  'turkey': 44,
#  'turkish': 29,
#  'turns': 26,
#  'u': 1063,
#  'uncovered': 11,
#  'union': 153,
#  'unita': 1,
#  'united': 545,
#  'valley': 29,
#  'vaunted': 6,
#  'victory': 173,
#  'violation': 24,
#  'virginia': 39,
#  'vote': 79,
#  'w': 36,
#  'war': 318,
#  'warton': 1,
#  'waters': 54,
#  'weapons': 88,
#  'weeks': 264,
#  'west': 212,
#  'while': 662,
#  'white': 179,
#  'wide': 87,
#  'withhold': 6,
#  'workers': 129,
#  'world': 510,
#  'xv': 1,
#  'years': 739,
#  'york': 266,
#  'yugoslav': 3,
#  'zambia': 1,
#  'zeppelin': 1,
#  'zone': 28,
#  'absorbed': 2,
#  'abstract': 3,
#  'across': 221,
#  'act': 76,
#  'adam': 15,
#  'adding': 119,
#  'addressed': 29,
#  'advantage': 49,
#  'afghanistan': 212,
#  'afternoon': 106,
#  'age': 74,
#  'aging': 6,
#  'aide': 24,
#  'air': 188,
#  'airport': 181,
#  'alexa': 4,
#  'allen': 26,
#  'allotment': 3,
#  'always': 102,
#  'america': 117,
#  'amidesk': 5,
#  'amp': 171,
#  'analysts': 204,
#  'anytime': 8,
#  'ap': 179,
#  'appreciation': 6,
#  'area': 290,
#  'arleigh': 3,
#  'arrest': 122,
#  'artist': 42,
#  'arts': 17,
#  'associated': 516,
#  'attractions': 12,
#  'available': 111,
#  'back': 517,
#  'bajak': 1,
#  'bath': 8,
#  'baths': 1,
#  'battleship': 3,
#  'be': 1426,
#  'because': 791,
#  'becoming': 43,
#  'been': 1179,
#  'began': 243,
#  'begins': 33,
#  'beijing': 61,
#  'below': 75,
#  'benefit': 29,
#  'bernard': 20,
#  'besieged': 9,
#  'betting': 14,
#  'big': 232,
#  'biggest': 160,
#  'bill': 126,
#  'bleary': 2,
#  'blogging': 4,
#  'boat': 47,
#  'bolivia': 8,
#  "bolivia's": 2,
#  'book': 44,
#  'boston': 34,
#  'bottom': 57,
#  'brain': 24,
#  'branch': 35,
#  'brock': 3,
#  'broken': 57,
#  'budapest': 15,
#  'build': 80,
#  'building': 132,
#  'bureaus': 9,
#  'burke': 11,
#  'business': 240,
#  'buzz': 4,
#  'california': 126,
#  'called': 376,
#  'can': 515,
#  'candor': 5,
#  'capital': 329,
#  'captains': 5,
#  'care': 85,
#  'carnage': 6,
#  'cars': 58,
#  'cast': 33,
#  'catch': 44,
#  'catholic': 25,
#  'center': 197,
#  'ceo': 48,
#  'change': 122,
#  'china': 174,
#  "china's": 86,
#  'class': 36,
#  'classified': 10,
#  'classroom': 6,
#  'closest': 17,
#  'clothing': 17,
#  'coast': 83,
#  'college': 56,
#  'coming': 165,
#  'communal': 3,
#  'companies': 157,
#  'company': 329,
#  'compensation': 37,
#  'concussions': 6,
#  'conroy': 6,
#  'consumer': 119,
#  'continue': 232,
#  'continues': 69,
#  'continuing': 70,
#  'convulsed': 2,
#  'cost': 157,
#  'cramped': 5,
#  'crazy': 18,
#  'creating': 29,
#  'creation': 39,
#  'criticizing': 4,
#  'crostini': 1,
#  'cruiser': 4,
#  'd': 77,
#  'daily': 98,
#  'dale': 55,
#  'damage': 73,
#  'dark': 13,
#  'david': 204,
#  "day's": 18,
#  'deadline': 56,
#  'dec': 309,
#  'decade': 81,
#  'decades': 92,
#  'deck': 16,
#  'defunct': 7,
#  'demand': 167,
#  'dentist': 2,
#  'desk': 8,
#  'despair': 1,
#  'desperate': 11,
#  'destroyer': 4,
#  'destroyers': 3,
#  "destroyer's": 3,
#  'devastating': 17,
#  'diamond': 6,
#  'digest': 15,
#  'dipper': 1,
#  'do': 358,
#  'doctor': 60,
#  'done': 86,
#  "don't": 221,
#  'dozens': 134,
#  'dr': 24,
#  'dressed': 21,
#  'drive': 77,
#  'drugs': 35,
#  'dual': 18,
#  'durable': 6,
#  'east': 132,
#  'eat': 20,
#  'eating': 12,
#  'ebay': 12,
#  'economic': 261,
#  'economist': 43,
#  'economy': 212,
#  'editors': 7,
#  'education': 36,
#  'election': 95,
#  'electronics': 51,
#  'emerging': 30,
#  'engine': 24,
#  'equity': 32,
#  'erin': 8,
#  'event': 123,
#  'every': 130,
#  'evo': 3,
#  'extravagant': 4,
#  'eyed': 10,
#  'eyes': 33,
#  'facebook': 16,
#  'fall': 112,
#  'far': 258,
#  'farr': 4,
#  'father': 100,
#  'fax': 9,
#  'feature': 18,
#  'features': 30,
#  'fewer': 40,
#  'filed': 85,
#  'film': 43,
#  'firms': 11,
#  'fisherman': 4,
#  'fishermen': 3,
#  'fishing': 24,
#  'follow': 49,
#  'food': 101,
#  'football': 110,
#  'forced': 103,
#  'fortitude': 6,
#  'found': 223,
#  'frank': 38,
#  'frigate': 3,
#  'fund': 83,
#  'gadget': 17,
#  'gain': 72,
#  'gains': 94,
#  'gardening': 11,
#  'geller': 3,
#  'generating': 12,
#  'glimpse': 10,
#  'global': 197,
#  'gloucester': 5,
#  'god': 20,
#  'goes': 77,
#  'going': 269,
#  'goods': 47,
#  'got': 206,
#  'green': 43,
#  'growth': 132,
#  'guarani': 2,
#  'guys': 21,
#  'hand': 155,
#  'hanging': 16,
#  'hannah': 2,
#  "hasn't": 75,
#  'health': 152,
#  'healthy': 20,
#  'helped': 195,
#  'here': 167,
#  'high': 501,
#  'higher': 191,
#  'hiv': 17,
#  'holiday': 78,
#  'home': 421,
#  'homeland': 82,
#  'homes': 109,
#  "honda's": 3,
#  'how': 349,
#  'hundreds': 154,
#  'hurst': 3,
#  'hursts': 2,
#  'if': 624,
#  'inc': 140,
#  'included': 161,
#  'index': 122,
#  'india': 85,
#  'indian': 71,
#  'indians': 13,
#  'individual': 54,
#  'industrial': 91,
#  'industrials': 25,
#  "industry's": 11,
#  'infrastructure': 16,
#  'initial': 85,
#  'international': 555,
#  'internet': 98,
#  'investments': 30,
#  'investors': 133,
#  'ipo': 4,
#  'ipos': 6,
#  'iron': 19,
#  'jack': 21,
#  'jay': 12,
#  'jersey': 50,
#  'joe': 34,
#  'john': 233,
#  'join': 58,
#  'juan': 36,
#  'just': 552,
#  'kind': 88,
#  'kitchen': 19,
#  'labor': 70,
#  'lagunillas': 1,
#  'laptops': 9,
#  'largely': 82,
#  'late': 362,
#  'leave': 141,
#  'lectures': 8,
#  'legs': 12,
#  'levels': 79,
#  'lifeline': 13,
#  'likely': 221,
#  'lindsay': 5,
#  'line': 184,
#  'linkedin': 4,
#  'list': 143,
#  'look': 136,
#  'looks': 34,
#  'loss': 119,
#  'lot': 148,
#  'maine': 13,
#  'manager': 103,
#  'manufactured': 6,
#  'manufacturers': 30,
#  'many': 513,
#  'market': 261,
#  'markets': 126,
#  'marlboro': 3,
#  'maryclaire': 2,
#  'material': 52,
#  'may': 383,
#  'maynardville': 2,
#  'meal': 4,
#  'meat': 6,
#  'medical': 110,
#  'men': 172,
#  'michael': 151,
#  'micro': 7,
#  'middle': 78,
#  'miller': 32,
#  'ministry': 203,
#  'moistening': 2,
#  'monday': 737,
#  'moore': 22,
#  'morales': 4,
#  'mostly': 82,
#  'move': 228,
#  'muslim': 165,
#  'navy': 12,
#  'nearly': 268,
#  'need': 222,
#  'networking': 9,
#  'never': 187,
#  'nonprofit': 11,
#  "norway's": 5,
#  'november': 285,
#  "ocean's": 5,
#  'offer': 115,
#  'offering': 88,
#  'offerings': 11,
#  'olesen': 2,
#  'onerous': 3,
#  'online': 74,
#  'operations': 144,
#  'order': 139,
#  'org': 49,
#  'outlasted': 3,
#  'outlook': 23,
#  'outspoken': 10,
#  'p': 104,
#  'pack': 9,
#  'paintings': 7,
#  'paradise': 2,
#  'past': 320,
#  'patients': 19,
#  'percent': 500,
#  'perform': 29,
#  'performance': 97,
#  'permits': 12,
#  'peter': 90,
#  'photo': 13,
#  'photos': 22,
#  'pipeline': 29,
#  'pitch': 31,
#  'place': 326,
#  'plans': 253,
#  'plenty': 24,
#  ...}

# %%
# TODO: Print the relative document frequency of 'the',
# i.e., the number of documents that contain 'the' divided by N.
print(term_appears['the']/N)
# Out:
# 0.9704823614110871

# %% [markdown]
# Empricially, we usually see better retrieval results if we rescale term frequency (within documents) and inverse document frequency (across documents) with the log function. Let the `tfidf` of term _t_ in document _d_ be:
# ```
# tfidf(t, d) = log(count(t, d) + 1) * log(N / df(t))
# ```
#
# Later in the course, we will show a probabilistic derivation of this quantity based on smoothing language models.

# %%
# TODO: Compute the tf-idf value for each term in each document.
# Take the raw term data and add a tfidf field to each record.
tfidf_terms = df.groupby(['term','id'], as_index = False).agg({'count': 'sum'})
list1=[]
for index,row in tfidf_terms.iterrows():
  list1.append(math.log(row[2] +1)*math.log(N/term_appears[row[0]]))
tfidf_terms['tf-idf'] = list1
tfidf_terms
# Out:
#            term                     id  count    tf-idf
# 0             a  APW_ENG_20100101.0001     16  0.219394
# 1             a  APW_ENG_20100102.0001     26  0.255217
# 2             a  APW_ENG_20100102.0002     27  0.258034
# 3             a  APW_ENG_20100102.0003     19  0.231978
# 4             a  APW_ENG_20100102.0005      4  0.124629
# ...         ...                    ...    ...       ...
# 524173   zverev  APW_ENG_20100105.0509      1  3.773895
# 524174   zverev  APW_ENG_20100105.0549      1  3.773895
# 524175  zvornik  APW_ENG_20100103.0487      1  5.496301
# 524176   zwolle  APW_ENG_20100106.0803      2  7.949931
# 524177   zwolle  APW_ENG_20100106.0878      2  7.949931
#
# [524178 rows x 4 columns]

# %%
# TODO: Print the 20 term-document pairs with the highest tf-idf values.
tfidf_terms=tfidf_terms.sort_values(by='tf-idf',ascending = False)
tfidf_terms[:20]
# Out:
#                term                     id  count     tf-idf
# 190626      guarani  APW_ENG_20100103.0028     24  23.292878
# 302847   nomination  APW_ENG_20100105.0061     95  22.519372
# 189036    greyhound  APW_ENG_20100105.0014     15  21.985205
# 279842      methane  APW_ENG_20100105.0446     15  21.985205
# 246828       kheire  APW_ENG_20100103.0015     14  21.473448
# 403298  shakespeare  APW_ENG_20100107.0036     18  21.306960
# 191048        guild  APW_ENG_20100105.0061     28  20.667543
# 403297  shakespeare  APW_ENG_20100106.0428     16  20.502093
# 268416        magna  APW_ENG_20100106.0075     12  20.338731
# 143101      elkhart  APW_ENG_20100102.0197     12  20.338731
# 435927       sutton  APW_ENG_20100106.1325     21  20.225285
# 464768        tohti  APW_ENG_20100104.0043     11  19.704034
# 282849       minhas  APW_ENG_20100107.0928     11  19.704034
# 189038   greyhounds  APW_ENG_20100105.0014     11  19.704034
# 249918        krewe  APW_ENG_20100107.0018     11  19.704034
# 405060      shiites  APW_ENG_20100104.0108     11  19.704034
# 358772         punk  APW_ENG_20100103.0016     14  19.596370
# 298135     netbooks  APW_ENG_20100105.1060     16  19.353324
# 298134     netbooks  APW_ENG_20100105.0997     16  19.353324
# 185698       golden  APW_ENG_20100105.0061     70  19.302647

# %% [markdown]
# ## Plotting Term Distributions
#
# Besides frequencies and tf-idf values within documents, it is often helpful to look at the distrubitions of word frequencies in the whole collection. In class, we talk about the Zipf distribution of word rank versus frequency and Heaps' Law relating the number of distinct words to the number of tokens.
#
# We might examine these distributions to see, for instance, if an unexpectedly large number of very rare terms occurs, which might indicate noise added to our data.

# %%
# TODO: Compute a list of the distinct words in this collection and sort it in descending order of frequency.
# Thus frequency[0] should contain the word "the" and the count 62216.
df = pd.DataFrame(terms)
frequency=list((df.groupby('term').sum('count').reset_index())[['term', 'count']].to_records(index=False))
frequency.sort(key=lambda x:x[1], reverse=True)
frequency
# Out:
# [('the', 62216),
#  ('to', 26931),
#  ('in', 25659),
#  ('a', 23383),
#  ('of', 22326),
#  ('and', 22125),
#  ('said', 10888),
#  ('for', 9716),
#  ('on', 9382),
#  ('that', 8942),
#  ('was', 7791),
#  ('is', 6317),
#  ('with', 6283),
#  ('at', 6078),
#  ('he', 5874),
#  ('it', 5357),
#  ('from', 5094),
#  ('as', 4746),
#  ('by', 4641),
#  ('has', 4355),
#  ('an', 4087),
#  ('have', 4012),
#  ('his', 3904),
#  ('be', 3693),
#  ('but', 3638),
#  ('s', 3567),
#  ('u', 3518),
#  ('were', 3478),
#  ('not', 3320),
#  ('are', 3218),
#  ('will', 3063),
#  ('its', 2955),
#  ('who', 2904),
#  ('had', 2900),
#  ('after', 2876),
#  ('year', 2816),
#  ('they', 2423),
#  ('this', 2331),
#  ('new', 2263),
#  ('been', 2241),
#  ('more', 2225),
#  ('two', 2136),
#  ('security', 2097),
#  ('or', 2076),
#  ('which', 2059),
#  ('about', 2003),
#  ('percent', 1966),
#  ('up', 1917),
#  ('their', 1898),
#  ('al', 1897),
#  ('would', 1851),
#  ('also', 1826),
#  ('last', 1807),
#  ('first', 1761),
#  ('than', 1748),
#  ('i', 1722),
#  ('one', 1717),
#  ('other', 1680),
#  ('people', 1678),
#  ('out', 1677),
#  ('government', 1659),
#  ('officials', 1628),
#  ('over', 1626),
#  ('when', 1622),
#  ('we', 1514),
#  ('police', 1497),
#  ('into', 1460),
#  ('no', 1460),
#  ('there', 1402),
#  ('against', 1266),
#  ('because', 1261),
#  ('since', 1244),
#  ('says', 1236),
#  ('time', 1236),
#  ('three', 1221),
#  ('could', 1215),
#  ('wednesday', 1195),
#  ('million', 1187),
#  ('monday', 1179),
#  ('years', 1144),
#  ('some', 1123),
#  ('before', 1107),
#  ('tuesday', 1095),
#  ('yemen', 1069),
#  ('all', 1067),
#  ('she', 1064),
#  ('united', 1058),
#  ('president', 1057),
#  ('her', 1036),
#  ('report', 1014),
#  ('day', 992),
#  ('international', 992),
#  ('while', 984),
#  ('official', 983),
#  ('second', 972),
#  ('down', 965),
#  ('only', 962),
#  ('him', 961),
#  ('if', 946),
#  ('qaida', 942),
#  ('states', 924),
#  ('told', 917),
#  ('world', 916),
#  ('old', 914),
#  ('off', 911),
#  ('attack', 886),
#  ('them', 878),
#  ('through', 868),
#  ('group', 866),
#  ('state', 858),
#  ('intelligence', 846),
#  ('month', 841),
#  ('killed', 839),
#  ('where', 836),
#  ('say', 831),
#  ('including', 820),
#  ('man', 811),
#  ('any', 802),
#  ('so', 790),
#  ('press', 781),
#  ('just', 777),
#  ('now', 776),
#  ('many', 773),
#  ('can', 760),
#  ('billion', 759),
#  ('south', 755),
#  ('still', 754),
#  ('during', 752),
#  ('back', 751),
#  ('high', 751),
#  ('minister', 745),
#  ('former', 742),
#  ('what', 740),
#  ('most', 735),
#  ('points', 735),
#  ('made', 724),
#  ('under', 718),
#  ('obama', 712),
#  ('four', 708),
#  ('thursday', 706),
#  ('country', 703),
#  ('company', 694),
#  ('city', 684),
#  ("it's", 683),
#  ('week', 676),
#  ('between', 675),
#  ('being', 667),
#  ('authorities', 666),
#  ('third', 664),
#  ('home', 663),
#  ('american', 661),
#  ('airport', 650),
#  ('associated', 649),
#  ('statement', 648),
#  ('court', 643),
#  ('top', 640),
#  ('did', 638),
#  ('set', 627),
#  ('sunday', 621),
#  ('national', 611),
#  ('later', 599),
#  ('those', 596),
#  ('us', 593),
#  ('you', 592),
#  ('five', 591),
#  ('rose', 584),
#  ('cup', 583),
#  ('like', 583),
#  ('then', 578),
#  ('several', 575),
#  ('oil', 572),
#  ('such', 572),
#  ('spokesman', 571),
#  ('house', 570),
#  ('season', 566),
#  ('match', 564),
#  ('both', 560),
#  ('game', 557),
#  ('make', 555),
#  ('afghanistan', 552),
#  ('may', 552),
#  ('saturday', 540),
#  ('get', 532),
#  ('even', 530),
#  ('expected', 530),
#  ('take', 522),
#  ('sales', 519),
#  ('british', 515),
#  ('open', 508),
#  ('another', 507),
#  ('britain', 507),
#  ('do', 507),
#  ('december', 506),
#  ('market', 506),
#  ('war', 506),
#  ('won', 506),
#  ('pakistan', 503),
#  ('passengers', 499),
#  ('well', 499),
#  ('left', 498),
#  ('win', 497),
#  ('team', 496),
#  ('washington', 493),
#  ('def', 491),
#  ('six', 490),
#  ('reported', 487),
#  ('cia', 481),
#  ('our', 480),
#  ('public', 478),
#  ('countries', 476),
#  ('according', 471),
#  ('least', 469),
#  ('economic', 468),
#  ('go', 468),
#  ('held', 468),
#  ('information', 468),
#  ('based', 467),
#  ('federal', 467),
#  ('months', 467),
#  ('how', 466),
#  ('called', 460),
#  ('capital', 460),
#  ('ministry', 460),
#  ('should', 459),
#  ('took', 457),
#  ('foreign', 456),
#  ('christmas', 452),
#  ('earlier', 452),
#  ('late', 450),
#  ('lead', 449),
#  ('news', 448),
#  ('militants', 445),
#  ('contributed', 444),
#  ('york', 444),
#  ('service', 443),
#  ('forces', 441),
#  ('failed', 440),
#  ('work', 439),
#  ('north', 437),
#  ('november', 435),
#  ('league', 432),
#  ('part', 430),
#  ('attacks', 429),
#  ('help', 429),
#  ('past', 427),
#  ('family', 426),
#  ('area', 425),
#  ('border', 425),
#  ('way', 425),
#  ('early', 422),
#  ('england', 420),
#  ('office', 418),
#  ('saying', 418),
#  ('chief', 417),
#  ('already', 415),
#  ('scored', 415),
#  ('next', 414),
#  ('military', 413),
#  ('minutes', 412),
#  ('run', 408),
#  ('long', 407),
#  ('led', 405),
#  ('around', 404),
#  ('end', 404),
#  ('without', 404),
#  ('added', 403),
#  ('embassy', 403),
#  ('seven', 403),
#  ('fell', 402),
#  ('much', 402),
#  ('vs', 402),
#  ('however', 401),
#  ('european', 398),
#  ('bank', 396),
#  ('major', 396),
#  ('whether', 395),
#  ('near', 394),
#  ('prices', 394),
#  ('china', 393),
#  ('dec', 389),
#  ('economy', 389),
#  ('support', 388),
#  ('yemeni', 388),
#  ('money', 387),
#  ('place', 387),
#  ('play', 387),
#  ('decision', 385),
#  ('days', 384),
#  ('agency', 383),
#  ('my', 382),
#  ('administration', 378),
#  ('until', 377),
#  ('white', 376),
#  ('among', 373),
#  ('came', 373),
#  ('recent', 373),
#  ("didn't", 372),
#  ('used', 370),
#  ('jan', 369),
#  ('west', 369),
#  ('final', 368),
#  ('france', 368),
#  ('deal', 367),
#  ('africa', 366),
#  ('use', 366),
#  ('flight', 363),
#  ('program', 363),
#  ('condition', 360),
#  ('aid', 359),
#  ('put', 359),
#  ('explosives', 358),
#  ('stock', 357),
#  ('half', 356),
#  ('power', 356),
#  ('dubai', 355),
#  ('israel', 354),
#  ('local', 354),
#  ('body', 353),
#  ('case', 353),
#  ('number', 353),
#  ('show', 352),
#  ('germany', 351),
#  ('iran', 350),
#  ('good', 349),
#  ('weeks', 348),
#  ('eight', 347),
#  ('games', 346),
#  ('officer', 345),
#  ('very', 345),
#  ('beat', 342),
#  ('going', 342),
#  ('leader', 340),
#  ('muslim', 339),
#  ('close', 337),
#  ('abdulmutallab', 336),
#  ('business', 336),
#  ('right', 336),
#  ('site', 334),
#  ('announced', 333),
#  ('own', 333),
#  ('results', 332),
#  ('trying', 332),
#  ('index', 331),
#  ('think', 331),
#  ('died', 330),
#  ('players', 330),
#  ('record', 330),
#  ('meeting', 329),
#  ('hit', 328),
#  ('region', 328),
#  ('suspected', 328),
#  ('lost', 327),
#  ('offer', 326),
#  ('ago', 325),
#  ('too', 324),
#  ('department', 323),
#  ('members', 323),
#  ('each', 322),
#  ('full', 322),
#  ('list', 322),
#  ('death', 321),
#  ('health', 320),
#  ('nearly', 320),
#  ('party', 319),
#  ('bomb', 318),
#  ('plans', 318),
#  ('trading', 318),
#  ('head', 315),
#  ('jobs', 315),
#  ('detroit', 314),
#  ('far', 314),
#  ('gaza', 312),
#  ('hours', 312),
#  ('russia', 312),
#  ('others', 310),
#  ('anti', 309),
#  ('following', 309),
#  ('give', 309),
#  ('system', 309),
#  ('began', 308),
#  ('found', 307),
#  ('point', 306),
#  ('markets', 305),
#  ('reports', 305),
#  ('few', 304),
#  ('test', 304),
#  ('defense', 303),
#  ('key', 302),
#  ('men', 302),
#  ('released', 302),
#  ('though', 302),
#  ('start', 301),
#  ('terror', 301),
#  ('ahead', 300),
#  ("country's", 299),
#  ('plane', 299),
#  ('ap', 298),
#  ('gas', 298),
#  ('higher', 298),
#  ('jordanian', 298),
#  ('london', 298),
#  ('friday', 297),
#  ('law', 296),
#  ('round', 296),
#  ('big', 295),
#  ('less', 294),
#  ('outside', 294),
#  ('price', 294),
#  ('see', 294),
#  ('workers', 294),
#  ('explosive', 291),
#  ('threat', 291),
#  ('analysts', 290),
#  ('need', 289),
#  ('these', 289),
#  ('central', 288),
#  ('terrorist', 288),
#  ('control', 287),
#  ("don't", 286),
#  ('tv', 286),
#  ('b', 285),
#  ('behind', 285),
#  ('charges', 285),
#  ('fourth', 285),
#  ('french', 285),
#  ('global', 285),
#  ('anonymity', 284),
#  ('return', 284),
#  ('australia', 283),
#  ('investors', 283),
#  ('sea', 283),
#  ('arrested', 282),
#  ('bill', 281),
#  ('further', 281),
#  ('bound', 280),
#  ('keep', 280),
#  ('corp', 279),
#  ('financial', 279),
#  ('gave', 279),
#  ('incident', 278),
#  ('prime', 278),
#  ('hamas', 277),
#  ('interest', 277),
#  ('killing', 277),
#  ('miles', 277),
#  ('d', 276),
#  ('likely', 276),
#  ('shot', 276),
#  ('comment', 275),
#  ('fight', 275),
#  ('flights', 275),
#  ('shares', 274),
#  ('away', 273),
#  ('director', 273),
#  ('move', 273),
#  ('played', 273),
#  ('air', 272),
#  ('life', 272),
#  ('same', 272),
#  ('across', 271),
#  ('c', 271),
#  ('john', 271),
#  ('possible', 271),
#  ('screening', 271),
#  ('airlines', 270),
#  ('terrorism', 269),
#  ('tried', 269),
#  ('companies', 268),
#  ('japanese', 268),
#  ('known', 268),
#  ('went', 267),
#  ('western', 266),
#  ('dollar', 265),
#  ('times', 264),
#  ('immediately', 263),
#  ('little', 263),
#  ('overall', 263),
#  ('accused', 262),
#  ('center', 262),
#  ('continue', 262),
#  ('counterterrorism', 262),
#  ('received', 262),
#  ('snow', 262),
#  ('efforts', 260),
#  ('fire', 260),
#  ('kilometers', 260),
#  ('tournament', 259),
#  ('de', 258),
#  ('nigerian', 258),
#  ('building', 257),
#  ('egyptian', 257),
#  ('groups', 257),
#  ('leaders', 257),
#  ('must', 257),
#  ('troops', 257),
#  ('along', 256),
#  ('amp', 256),
#  ('better', 256),
#  ('co', 256),
#  ('political', 256),
#  ('election', 255),
#  ('northwest', 254),
#  ('david', 253),
#  ('plan', 253),
#  ('prison', 253),
#  ('got', 252),
#  ("world's", 252),
#  ('general', 251),
#  ('iraq', 251),
#  ('never', 251),
#  ('come', 250),
#  ('side', 250),
#  ('want', 250),
#  ('food', 249),
#  ('web', 249),
#  ('goal', 248),
#  ('might', 248),
#  ('quarter', 248),
#  ('sent', 248),
#  ('working', 248),
#  ('taken', 247),
#  ('taliban', 247),
#  ('victory', 246),
#  ('attempt', 245),
#  ('spoke', 245),
#  ('manufacturing', 243),
#  ('measures', 243),
#  ('senior', 243),
#  ('whose', 243),
#  ('car', 242),
#  ('cash', 242),
#  ('clear', 242),
#  ('training', 242),
#  ('recovery', 241),
#  ('best', 240),
#  ('demand', 240),
#  ('share', 240),
#  ('spain', 240),
#  ('club', 239),
#  ('due', 239),
#  ('growth', 239),
#  ("i'm", 239),
#  ('inc', 239),
#  ('officers', 239),
#  ('province', 239),
#  ('series', 239),
#  ('abu', 238),
#  ('closed', 238),
#  ('dead', 238),
#  ('southern', 238),
#  ('suspect', 238),
#  ('face', 237),
#  ('level', 237),
#  ('pay', 237),
#  ('helped', 236),
#  ('october', 236),
#  ('small', 236),
#  ('egypt', 235),
#  ('nations', 235),
#  ('really', 235),
#  ('water', 235),
#  ('airline', 233),
#  ('base', 233),
#  ('euro', 233),
#  ('activists', 232),
#  ('east', 231),
#  ('force', 231),
#  ('italy', 231),
#  ('player', 231),
#  ('writer', 231),
#  ('charged', 230),
#  ('children', 230),
#  ('know', 230),
#  ('nine', 230),
#  ('showed', 230),
#  ('total', 230),
#  ('operations', 229),
#  ('data', 228),
#  ('main', 228),
#  ('nuclear', 228),
#  ('once', 228),
#  ('suicide', 228),
#  ('union', 228),
#  ('james', 227),
#  ('march', 226),
#  ('rate', 226),
#  ('airports', 225),
#  ('me', 225),
#  ('stop', 225),
#  ('allowed', 224),
#  ('conference', 224),
#  ('cost', 224),
#  ('drug', 224),
#  ('media', 224),
#  ('chinese', 223),
#  ('bomber', 222),
#  ('japan', 222),
#  ('ordered', 222),
#  ('straight', 222),
#  ('yet', 222),
#  ('cuba', 221),
#  ('europe', 221),
#  ('n', 219),
#  ('per', 219),
#  ('nation', 218),
#  ('afghan', 217),
#  ('making', 217),
#  ('net', 217),
#  ('crude', 215),
#  ('february', 215),
#  ('given', 215),
#  ('injured', 215),
#  ('issue', 215),
#  ('taking', 215),
#  ('energy', 214),
#  ('army', 213),
#  ('bombing', 213),
#  ('figures', 213),
#  ('pakistani', 213),
#  ('board', 212),
#  ('democrats', 212),
#  ('agreed', 211),
#  ('strike', 211),
#  ('again', 210),
#  ('investigation', 210),
#  ('judge', 210),
#  ('name', 210),
#  ('rights', 210),
#  ('situation', 210),
#  ('yen', 210),
#  ('barack', 209),
#  ('enough', 209),
#  ('problems', 209),
#  ('cents', 208),
#  ('here', 208),
#  ('meet', 208),
#  ('job', 207),
#  ('seconds', 207),
#  ('tax', 207),
#  ("year's", 207),
#  ('become', 206),
#  ('increase', 206),
#  ('tour', 206),
#  ('despite', 205),
#  ('does', 205),
#  ('areas', 204),
#  ('westergaard', 204),
#  ('line', 203),
#  ('low', 203),
#  ('member', 203),
#  ('largest', 202),
#  ('http', 201),
#  ('israeli', 201),
#  ('kraft', 201),
#  ('private', 201),
#  ('street', 200),
#  ('australian', 199),
#  ('cut', 199),
#  ('field', 199),
#  ('hospital', 199),
#  ('leading', 199),
#  ('crisis', 198),
#  ('worst', 198),
#  ('able', 197),
#  ('northern', 197),
#  ('scanners', 197),
#  ('talks', 197),
#  ('hard', 196),
#  ('opening', 196),
#  ('believe', 195),
#  ('cold', 195),
#  ('confirmed', 195),
#  ('future', 195),
#  ('june', 195),
#  ('seen', 195),
#  ('spokeswoman', 195),
#  ('asked', 194),
#  ('thousands', 194),
#  ('using', 194),
#  ('violence', 194),
#  ("that's", 193),
#  ('try', 193),
#  ('eu', 192),
#  ('moved', 192),
#  ('provide', 192),
#  ('wall', 192),
#  ('agreement', 191),
#  ('community', 191),
#  ('meters', 191),
#  ('real', 191),
#  ('average', 190),
#  ('construction', 190),
#  ('ended', 190),
#  ('experts', 190),
#  ('spending', 190),
#  ('additional', 189),
#  ('attorney', 189),
#  ('debt', 189),
#  ('hundreds', 189),
#  ('night', 189),
#  ('palestinian', 189),
#  ('services', 189),
#  ('weather', 189),
#  ('coming', 188),
#  ('declined', 188),
#  ('opposition', 188),
#  ('activity', 187),
#  ('although', 187),
#  ('details', 187),
#  ('feet', 187),
#  ('ground', 187),
#  ('met', 187),
#  ('post', 187),
#  ('town', 187),
#  ('within', 187),
#  ('caused', 186),
#  ('coach', 186),
#  ('latest', 186),
#  ('swiss', 186),
#  ('free', 185),
#  ('double', 184),
#  ('el', 184),
#  ('internet', 184),
#  ('lot', 184),
#  ('reached', 184),
#  ('winning', 184),
#  ('biggest', 183),
#  ('finished', 183),
#  ('include', 183),
#  ('large', 183),
#  ('leave', 183),
#  ('often', 183),
#  ('recession', 183),
#  ('soldiers', 183),
#  ('travel', 183),
#  ('wounded', 183),
#  ('break', 182),
#  ('islamic', 182),
#  ('los', 182),
#  ('mixed', 182),
#  ('paul', 182),
#  ('strong', 182),
#  ('exchange', 181),
#  ('looking', 181),
#  ('ball', 180),
#  ('cadbury', 180),
#  ('employees', 180),
#  ('interior', 180),
#  ('switzerland', 180),
#  ('toward', 180),
#  ('austria', 179),
#  ('irish', 179),
#  ('consumer', 178),
#  ('german', 178),
#  ('india', 178),
#  ('look', 178),
#  ('playing', 178),
#  ('september', 178),
#  ('finance', 177),
#  ('interview', 177),
#  ('order', 177),
#  ('parliament', 177),
#  ('secretary', 177),
#  ('brown', 176),
#  ('johnson', 176),
#  ('remain', 176),
#  ('risk', 176),
#  ('believed', 175),
#  ('hold', 175),
#  ('human', 175),
#  ('jordan', 175),
#  ('kill', 175),
#  ('reporters', 175),
#  ('americans', 174),
#  ('eastern', 174),
#  ('senate', 174),
#  ('tribal', 174),
#  ('writers', 174),
#  ('young', 174),
#  ('amid', 173),
#  ('governments', 173),
#  ('great', 173),
#  ('morning', 173),
#  ('unemployment', 173),
#  ('appeared', 172),
#  ('clinton', 172),
#  ('contract', 172),
#  ('history', 172),
#  ('lower', 172),
#  ('potential', 172),
#  ('race', 172),
#  ('threats', 172),
#  ('angeles', 171),
#  ('bin', 171),
#  ('included', 171),
#  ('industry', 171),
#  ('reach', 171),
#  ('teams', 171),
#  ('canada', 170),
#  ('january', 170),
#  ('michael', 170),
#  ('peace', 170),
#  ('seeking', 170),
#  ('turned', 170),
#  ('watch', 170),
#  ('alleged', 169),
#  ('arenas', 169),
#  ('career', 169),
#  ('minute', 169),
#  ('seeded', 169),
#  ('slovak', 169),
#  ('dropped', 168),
#  ('find', 168),
#  ('football', 168),
#  ("obama's", 168),
#  ('person', 168),
#  ('project', 168),
#  ('serious', 168),
#  ('soon', 168),
#  ('stage', 168),
#  ('wanted', 168),
#  ('balawi', 167),
#  ('california', 167),
#  ('claims', 167),
#  ('hand', 167),
#  ('henin', 167),
#  ('homes', 167),
#  ('loss', 167),
#  ('rising', 167),
#  ('room', 167),
#  ('authorized', 166),
#  ('blast', 166),
#  ('involved', 166),
#  ('technology', 166),
#  ('trade', 166),
#  ('arrest', 165),
#  ('development', 165),
#  ('parts', 165),
#  ('policy', 165),
#  ('woman', 165),
#  ('burj', 164),
#  ('charge', 164),
#  ('school', 164),
#  ('smith', 164),
#  ('somalia', 164),
#  ('today', 164),
#  ('university', 164),
#  ('anderson', 163),
#  ('claimed', 163),
#  ('prosecutors', 163),
#  ('shooting', 163),
#  ('stay', 163),
#  ('buy', 162),
#  ('fired', 162),
#  ('indian', 162),
#  ('signs', 162),
#  ('ady', 161),
#  ('arab', 161),
#  ('arrived', 161),
#  ('deaths', 161),
#  ('provided', 161),
#  ('stocks', 161),
#  ('strikes', 161),
#  ('change', 160),
#  ('event', 160),
#  ('goals', 160),
#  ("he's", 160),
#  ('island', 160),
#  ('safety', 160),
#  ('singles', 160),
#  ('tennis', 160),
#  ('care', 159),
#  ('struck', 159),
#  ('barrel', 158),
#  ('credit', 158),
#  ('m', 158),
#  ('previous', 158),
#  ('rates', 158),
#  ('remains', 158),
#  ('republican', 158),
#  ('returned', 158),
#  ('term', 158),
#  ('vehicles', 158),
#  ('review', 157),
#  ('scheduled', 157),
#  ('terms', 157),
#  ('almost', 156),
#  ('crew', 156),
#  ('manchester', 156),
#  ('planned', 156),
#  ('www', 156),
#  ('detained', 155),
#  ('foundation', 155),
#  ('medical', 155),
#  ("pakistan's", 155),
#  ('production', 155),
#  ('raised', 155),
#  ('drop', 154),
#  ('karzai', 154),
#  ('opened', 154),
#  ('whaling', 154),
#  ('google', 153),
#  ("government's", 153),
#  ('leaving', 153),
#  ('nigeria', 153),
#  ('rally', 153),
#  ('saudi', 153),
#  ('terrorists', 153),
#  ('video', 153),
#  ('action', 152),
#  ('call', 152),
#  ('civilian', 152),
#  ('district', 152),
#  ('elections', 152),
#  ('guard', 152),
#  ('identified', 152),
#  ('operation', 152),
#  ('pressure', 152),
#  ('concerns', 151),
#  ('dozens', 151),
#  ('fuel', 151),
#  ('phone', 151),
#  ('speaking', 151),
#  ('america', 150),
#  ('bag', 150),
#  ('carried', 150),
#  ('democratic', 150),
#  ('film', 150),
#  ('kenya', 150),
#  ('meanwhile', 150),
#  ('sign', 150),
#  ('changes', 149),
#  ('florida', 149),
#  ('lawyer', 149),
#  ('visit', 149),
#  ('bring', 148),
#  ('church', 148),
#  ('com', 148),
#  ('danish', 148),
#  ('forward', 148),
#  ('growing', 148),
#  ('having', 148),
#  ('hopes', 148),
#  ('luggage', 148),
#  ('process', 148),
#  ('running', 148),
#  ('special', 148),
#  ('calls', 147),
#  ('recently', 147),
#  ('republic', 147),
#  ('research', 147),
#  ('vote', 147),
#  ('airliner', 146),
#  ('armed', 146),
#  ('attempted', 146),
#  ('broke', 146),
#  ('champion', 146),
#  ('course', 146),
#  ('czech', 146),
#  ('increased', 146),
#  ('khan', 146),
#  ('standard', 146),
#  ('yards', 146),
#  ('considered', 145),
#  ('fifth', 145),
#  ('moving', 145),
#  ('rise', 145),
#  ('rules', 145),
#  ('stopped', 145),
#  ('hour', 144),
#  ('management', 144),
#  ('natural', 144),
#  ('sector', 144),
#  ('analyst', 143),
#  ('blow', 143),
#  ("doesn't", 143),
#  ('embassies', 143),
#  ('murder', 143),
#  ('passenger', 143),
#  ('port', 143),
#  ('ship', 143),
#  ('somali', 143),
#  ('civilians', 142),
#  ('clash', 142),
#  ('futures', 142),
#  ('manager', 142),
#  ('mass', 142),
#  ('network', 142),
#  ('period', 142),
#  ('shepherd', 142),
#  ('why', 142),
#  ('matter', 141),
#  ('palestinians', 141),
#  ('role', 141),
#  ("there's", 141),
#  ('thought', 141),
#  ('worked', 141),
#  ('agencies', 140),
#  ('born', 140),
#  ('brennan', 140),
#  ...]

# %%
# TODO: Plot a graph of the log of the rank (starting at 1) on the x-axis,
# against the log of the frequency on the y-axis. You may use the matplotlib
# or other library.
import numpy as np
plt.plot(np.log(range(1,len(frequency)+1)),np.log([inner_list[1] for inner_list in frequency]))
plt.xlabel('log(index)')
plt.ylabel('log(frequency)')
# Out:
# Text(0, 0.5, 'log(frequency)')

# %%
# TODO: Compute the number of tokens in the corpus.
# Remember to count each occurrence of each word. For instance, the 62,216
# instances of "the" will all count here.
ntokens = 0
df = df.groupby('term').sum('count').sort_values(by="count", ascending=False)
ntokens = df['count'].sum()
ntokens
# Out:
# 1000000

# %%
# TODO: Compute the proportion of tokens made up by the top 10 most
# frequent words.
df[:10].sum()/ntokens
# Out:
# count    0.221568
# dtype: float64

# %%
# TODO: Compute the proportion of tokens made up by the words that occur
# exactly once in this collection.
df[df['count'] == 1].sum() / ntokens
# Out:
# count    0.006641
# dtype: float64

# %% [markdown]
# ## Acquiring New Documents (for CS6200)
#
# For this assignment so far, you've worked with data that's already been extracted, tokenized, and counted. In this final section, you'll explore acquiring new data.
#
# One common way of acquiring data is through application programming interfaces (APIs) to various databases. The Library of Congress's [_Chronicling America_](https://chroniclingamerica.loc.gov/) site aggregates digitized US newspapers from the past two hundred years, such as the [_Seattle Star_](https://chroniclingamerica.loc.gov/lccn/sn87093407/1923-09-22/ed-1/seq-1/) from 100 years ago.
#
# You can use [the API](https://chroniclingamerica.loc.gov/about/api/) to retrieve JSON data listing all issues of the _Seattle Star_: https://chroniclingamerica.loc.gov/lccn/sn87093407.json
#
# Note the list in the `issues` field. For example, here is the record for the September 22, 1923, issue: https://chroniclingamerica.loc.gov/lccn/sn87093407/1923-09-22/ed-1.json
#
# In that issue record, you'll see records for each page, e.g.: https://chroniclingamerica.loc.gov/lccn/sn87093407/1923-09-22/ed-1/seq-1.json
#
# And inside that page record, you'll see links to data about that page in various data formats, such as JPEG, PDF, and plain text, which is what we want here: https://chroniclingamerica.loc.gov/lccn/sn87093407/1923-09-22/ed-1/seq-1/ocr.txt
#
# This plain text was transcribed from the old page images using optical character recognition (OCR) models, and so contains errors.
#
# Your task is to acquire and analyze the issues of the _Seattle Star_ from the month of September, 1923, i.e., the issues with a date field that starts with `1923-09`. This should be about the same amount of data as the million words from the Associated Press you analyzed in the last section.

# %% [markdown]
# **TODO**: Write code that calls the _Chronicling America_ API to download and extract the text from the _Seattle Star_ from September 1923. You can use the `json` library from above and any other libraries you wish to fetch data from URLs. As you would when working with any production API, you may need to limit your rate of requests.

# %%
# TODO: Data acquisition code here.

# %% [markdown]
# **TODO**: Write code to tokenize the text and count the resulting terms in each document. Since this data comes from automatically transcribing printed pages, some words may be hyphenated across line breaks. There is more than one right way to tokenize this data, so add comments to your code documenting your choices.

# %%
# TODO: Tokenization code here.

# %% [markdown]
# **TODO**: Plot a graph of the log rank against log frequency for your collection, as you did for the sample collection above.

# %%
# TODO: Plotting code here.

# %% [markdown]
# **TODO**: What do you observe about the differences between the distributions of the Associated Press and Seattle Star collections? In this text box, give some possible reasons for these differences.
